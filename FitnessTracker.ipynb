# %% [markdown]
# <a href="https://colab.research.google.com/github/surajjorwar/FitnessTracker/blob/main/FitnessTracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from glob import glob

# %%
single_csv = pd.read_csv("/content/drive/MyDrive/FitnessTracker/FitnessTracker/data-science-template-main/data/raw/MetaMotion/A-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv")

# %%
single_csv.head()
# Out:
#       epoch (ms)             time (01:00)  elapsed (s)  x-axis (g)  \
# 0  1547219408431  2019-01-11T16:10:08.431         0.00       0.010
# 1  1547219408511  2019-01-11T16:10:08.511         0.08       0.000
# 2  1547219408591  2019-01-11T16:10:08.591         0.16       0.001
# 3  1547219408671  2019-01-11T16:10:08.671         0.24      -0.012
# 4  1547219408751  2019-01-11T16:10:08.751         0.32      -0.013
#
#    y-axis (g)  z-axis (g)
# 0       0.964      -0.087
# 1       0.961      -0.069
# 2       0.974      -0.087
# 3       0.971      -0.084
# 4       0.954      -0.094

# %%
files = glob('/content/drive/MyDrive/FitnessTracker/FitnessTracker/data-science-template-main/data/raw/MetaMotion/*csv')

# %%
len(files)
# Out:
# 187

# %%
data_Path = '/content/drive/MyDrive/FitnessTracker/FitnessTracker/data-science-template-main/data/raw/MetaMotion/'

# %%
#extract feature from file
f = files[2]
f = f.replace(data_Path,'')
participant = f.split("-")[0]
label = f.split("-")[1]
category = f.split("-")[2].rstrip("13MetaWear_2019")

# %%
f
# Out:
# 'C-squat-heavy_MetaWear_2019-01-15T20.11.55.634_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv'

# %%
print(participant) # the letter B
print(label)
print(category)
# Out:
# C
# squat
# heavy

# %%
df = pd.read_csv(files[13])

# %%
df.head(4)
# Out:
#       epoch (ms)             time (01:00)  elapsed (s)  x-axis (g)  \
# 0  1547221363566  2019-01-11T16:42:43.566         0.00      -0.136
# 1  1547221363646  2019-01-11T16:42:43.646         0.08      -0.143
# 2  1547221363726  2019-01-11T16:42:43.726         0.16      -0.187
# 3  1547221363806  2019-01-11T16:42:43.806         0.24      -0.152
#
#    y-axis (g)  z-axis (g)
# 0       0.986      -0.053
# 1       0.977      -0.053
# 2       0.935       0.039
# 3       0.958      -0.075

# %%
df['participant'] = participant
df['label'] = label
df['category'] = category

# %%
df.head(2)
# Out:
#       epoch (ms)             time (01:00)  elapsed (s)  x-axis (g)  \
# 0  1547221363566  2019-01-11T16:42:43.566         0.00      -0.136
# 1  1547221363646  2019-01-11T16:42:43.646         0.08      -0.143
#
#    y-axis (g)  z-axis (g) participant  label category
# 0       0.986      -0.053           C  squat    heavy
# 1       0.977      -0.053           C  squat    heavy

# %%
acc_df = pd.DataFrame()
gyr_df = pd.DataFrame()

# %%
acc_set = 1
gyr_set = 1

# %%
for f in files:
  df = pd.read_csv(f)

  f = f.replace(data_Path,'')
  participant = f.split("-")[0]
  label = f.split("-")[1]
  category = f.split("-")[2].rstrip("13MetaWear_2019")


  df['participant'] = participant
  df['label'] = label
  df['category'] = category

  if "Accelerometer" in f:
    df['set'] = acc_set
    acc_set += 1
    acc_df = pd.concat([acc_df,df])

  if "Gyroscope" in f:
    df['set'] = acc_set
    gyr_set += 1
    gyr_df = pd.concat([gyr_df,df])

# %%
acc_df.head()
# Out:
#                          x-axis (g)  y-axis (g)  z-axis (g) participant label  \
# epoch (ms)
# 2019-01-14 14:05:37.530      -0.015      -0.938       0.052           C   row
# 2019-01-14 14:05:37.610      -0.031      -0.979       0.017           C   row
# 2019-01-14 14:05:37.690      -0.036      -1.036      -0.042           C   row
# 2019-01-14 14:05:37.770      -0.021      -1.044      -0.023           C   row
# 2019-01-14 14:05:37.850      -0.021      -1.053      -0.040           C   row
#
#                         category  set
# epoch (ms)
# 2019-01-14 14:05:37.530    heavy    1
# 2019-01-14 14:05:37.610    heavy    1
# 2019-01-14 14:05:37.690    heavy    1
# 2019-01-14 14:05:37.770    heavy    1
# 2019-01-14 14:05:37.850    heavy    1

# %%
gyr_df.head()
# Out:
#       epoch (ms)             time (01:00)  elapsed (s)  x-axis (deg/s)  \
# 0  1547474499893  2019-01-14T15:01:39.893         0.00          -6.890
# 1  1547474499933  2019-01-14T15:01:39.933         0.04          -7.439
# 2  1547474499973  2019-01-14T15:01:39.973         0.08         -10.488
# 3  1547474500013  2019-01-14T15:01:40.013         0.12         -15.488
# 4  1547474500053  2019-01-14T15:01:40.053         0.16         -22.927
#
#    y-axis (deg/s)  z-axis (deg/s) participant label category  set
# 0          -0.305          -3.841           C   row   medium    4
# 1           0.122          -4.024           C   row   medium    4
# 2          -0.671          -6.768           C   row   medium    4
# 3           4.390          -7.256           C   row   medium    4
# 4           0.549          -5.488           C   row   medium    4

# %% [markdown]
# date time

# %%
acc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23578 entries, 0 to 265
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   epoch (ms)    23578 non-null  int64
#  1   time (01:00)  23578 non-null  object
#  2   elapsed (s)   23578 non-null  float64
#  3   x-axis (g)    23578 non-null  float64
#  4   y-axis (g)    23578 non-null  float64
#  5   z-axis (g)    23578 non-null  float64
#  6   participant   23578 non-null  object
#  7   label         23578 non-null  object
#  8   category      23578 non-null  object
#  9   set           23578 non-null  int64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 2.0+ MB

# %%
pd.to_datetime(acc_df['epoch (ms)'],unit= 'ms')
pd.to_datetime(gyr_df['epoch (ms)'],unit= 'ms')
# Out:
# 0     2019-01-14 14:01:39.893
# 1     2019-01-14 14:01:39.933
# 2     2019-01-14 14:01:39.973
# 3     2019-01-14 14:01:40.013
# 4     2019-01-14 14:01:40.053
#                 ...
# 833   2019-01-18 16:46:23.293
# 834   2019-01-18 16:46:23.333
# 835   2019-01-18 16:46:23.373
# 836   2019-01-18 16:46:23.413
# 837   2019-01-18 16:46:23.453
# Name: epoch (ms), Length: 47218, dtype: datetime64[ns]

# %%
acc_df.index = pd.to_datetime(acc_df['epoch (ms)'],unit= 'ms')
gyr_df.index = pd.to_datetime(gyr_df['epoch (ms)'],unit= 'ms')

# %%
acc_df.head(2)
# Out:
#                             epoch (ms)             time (01:00)  elapsed (s)  \
# epoch (ms)
# 2019-01-14 14:05:37.530  1547474737530  2019-01-14T15:05:37.530         0.00
# 2019-01-14 14:05:37.610  1547474737610  2019-01-14T15:05:37.610         0.08
#
#                          x-axis (g)  y-axis (g)  z-axis (g) participant label  \
# epoch (ms)
# 2019-01-14 14:05:37.530      -0.015      -0.938       0.052           C   row
# 2019-01-14 14:05:37.610      -0.031      -0.979       0.017           C   row
#
#                         category  set
# epoch (ms)
# 2019-01-14 14:05:37.530    heavy    1
# 2019-01-14 14:05:37.610    heavy    1

# %%
del acc_df['epoch (ms)']
del acc_df['time (01:00)']
del acc_df['elapsed (s)']


del gyr_df['epoch (ms)']
del gyr_df['time (01:00)']
del gyr_df['elapsed (s)']

# %% [markdown]
# Function for all above task

# %%
def read_data_file(files):
  for f in files:

      acc_df = pd.DataFrame()
      gyr_df = pd.DataFrame()

      acc_set = 1
      gyr_set = 1

      df = pd.read_csv(f)

      data_Path = '/content/drive/MyDrive/FitnessTracker/FitnessTracker/data-science-template-main/data/raw/MetaMotion/'
      f = f.replace(data_Path,'')
      participant = f.split("-")[0]
      label = f.split("-")[1]
      category = f.split("-")[2].rstrip("13MetaWear_2019")


      df['participant'] = participant
      df['label'] = label
      df['category'] = category

      if "Accelerometer" in f:
        df['set'] = acc_set
        acc_set += 1
        acc_df = pd.concat([acc_df,df])

      if "Gyroscope" in f:
        df['set'] = acc_set
        gyr_set += 1
        gyr_df = pd.concat([gyr_df,df])
  acc_df.index = pd.to_datetime(acc_df['epoch (ms)'],unit= 'ms')
  gyr_df.index = pd.to_datetime(gyr_df['epoch (ms)'],unit= 'ms')

  del acc_df["epoch (ms)"]
  del acc_df['time (01:00)']
  del acc_df['elapsed (s)']


  del gyr_df["epoch (ms)"]
  del gyr_df['time (01:00)']
  del gyr_df['elapsed (s)']

  return acc_df,gyr_df
acc_df,gyr_df = read_data_file(files)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-144-0f525ec2c691> in <cell line: 45>()
#      43
#      44   return acc_df,gyr_df
# ---> 45 acc_df,gyr_df = read_data_file(files)
#
# <ipython-input-144-0f525ec2c691> in read_data_file(files)
#      31         gyr_df = pd.concat([gyr_df,df])
#      32   acc_df.index = pd.to_datetime(acc_df['epoch (ms)'],unit= 'ms')
# ---> 33   gyr_df.index = pd.to_datetime(gyr_df['epoch (ms)'],unit= 'ms')
#      34
#      35   del acc_df["epoch (ms)"]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     347                 raise KeyError(key) from err
#     348         if isinstance(key, Hashable):
# --> 349             raise KeyError(key)
#     350         self._check_indexing_error(key)
#     351         raise KeyError(key)
#
# KeyError: 'epoch (ms)'

# %%
acc_df,gyr_df = read_data_file(files)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-142-9f1946069c25> in <cell line: 1>()
# ----> 1 read_data_file(files)
#
# <ipython-input-141-341eb496a218> in read_data_file(files)
#      31         gyr_df = pd.concat([gyr_df,df])
#      32   acc_df.index = pd.to_datetime(acc_df['epoch (ms)'],unit= 'ms')
# ---> 33   gyr_df.index = pd.to_datetime(gyr_df['epoch (ms)'],unit= 'ms')
#      34
#      35   del acc_df["epoch (ms)"]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     347                 raise KeyError(key) from err
#     348         if isinstance(key, Hashable):
# --> 349             raise KeyError(key)
#     350         self._check_indexing_error(key)
#     351         raise KeyError(key)
#
# KeyError: 'epoch (ms)'

# %%
acc_df
