# %% [markdown]
# <a href="https://colab.research.google.com/github/surajjorwar/FitnessTracker/blob/main/FitnessTracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Read single CSV file

# %%
import pandas as pd
from glob import glob

# %%
single_csv = pd.read_csv("/content/drive/MyDrive/FitnessTracker/FitnessTracker/data-science-template-main/data/raw/MetaMotion/A-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv")
single_csv.head(2)
# Out:
#       epoch (ms)             time (01:00)  elapsed (s)  x-axis (g)  \
# 0  1547219408431  2019-01-11T16:10:08.431         0.00        0.01
# 1  1547219408511  2019-01-11T16:10:08.511         0.08        0.00
#
#    y-axis (g)  z-axis (g)
# 0       0.964      -0.087
# 1       0.961      -0.069

# %% [markdown]
# # List all data in data/raw/MetaMotion

# %%
files = glob('/content/drive/MyDrive/FitnessTracker/FitnessTracker/data-science-template-main/data/raw/MetaMotion/*csv')
len(files)
# Out:
# 187

# %%
df = pd.read_csv(files[13])
df.head(2)
# Out:
#       epoch (ms)             time (01:00)  elapsed (s)  x-axis (g)  \
# 0  1547221363566  2019-01-11T16:42:43.566         0.00      -0.136
# 1  1547221363646  2019-01-11T16:42:43.646         0.08      -0.143
#
#    y-axis (g)  z-axis (g)
# 0       0.986      -0.053
# 1       0.977      -0.053

# %% [markdown]
# # Extract features from filename

# %%
#extract feature from file
data_Path = '/content/drive/MyDrive/FitnessTracker/FitnessTracker/data-science-template-main/data/raw/MetaMotion/'
f = files[2]
f = f.replace(data_Path,'')
participant = f.split("-")[0]
label = f.split("-")[1]
category = f.split("-")[2].rstrip("13MetaWear_2019")

# %%
df['participant'] = participant
df['label'] = label
df['category'] = category


df['participant'] = participant
df['label'] = label
df['category'] = category

# %% [markdown]
# # Read all files

# %%
acc_df = pd.DataFrame()
gyr_df = pd.DataFrame()

acc_set = 1
gyr_set = 1

for f in files:
  df = pd.read_csv(f)

  f = f.replace(data_Path,'')
  participant = f.split("-")[0]
  label = f.split("-")[1]
  category = f.split("-")[2].rstrip("13MetaWear_2019")


  df['participant'] = participant
  df['label'] = label
  df['category'] = category

  if "Accelerometer" in f:
    df['set'] = acc_set
    acc_set += 1
    acc_df = pd.concat([acc_df,df])

  if "Gyroscope" in f:
    df['set'] = acc_set
    gyr_set += 1
    gyr_df = pd.concat([gyr_df,df])

# %%
acc_df.head(2)
# Out:
#       epoch (ms)             time (01:00)  elapsed (s)  x-axis (g)  \
# 0  1547474737530  2019-01-14T15:05:37.530         0.00      -0.015
# 1  1547474737610  2019-01-14T15:05:37.610         0.08      -0.031
#
#    y-axis (g)  z-axis (g) participant label category  set
# 0      -0.938       0.052           C   row    heavy    1
# 1      -0.979       0.017           C   row    heavy    1

# %%
gyr_df.head(2)
# Out:
#       epoch (ms)             time (01:00)  elapsed (s)  x-axis (deg/s)  \
# 0  1547474499893  2019-01-14T15:01:39.893         0.00          -6.890
# 1  1547474499933  2019-01-14T15:01:39.933         0.04          -7.439
#
#    y-axis (deg/s)  z-axis (deg/s) participant label category  set
# 0          -0.305          -3.841           C   row   medium    4
# 1           0.122          -4.024           C   row   medium    4

# %% [markdown]
# # Working with datetimes

# %%
acc_df.index = pd.to_datetime(acc_df['epoch (ms)'],unit= 'ms')
gyr_df.index = pd.to_datetime(gyr_df['epoch (ms)'],unit= 'ms')

del acc_df["epoch (ms)"]
del acc_df['time (01:00)']
del acc_df['elapsed (s)']


del gyr_df["epoch (ms)"]
del gyr_df['time (01:00)']
del gyr_df['elapsed (s)']

# %%
acc_df.head(2)
# Out:
#                          x-axis (g)  y-axis (g)  z-axis (g) participant label  \
# epoch (ms)
# 2019-01-14 14:05:37.530      -0.015      -0.938       0.052           C   row
# 2019-01-14 14:05:37.610      -0.031      -0.979       0.017           C   row
#
#                         category  set
# epoch (ms)
# 2019-01-14 14:05:37.530    heavy    1
# 2019-01-14 14:05:37.610    heavy    1

# %% [markdown]
# # Turn into function

# %%
def read_data_file(files):
  acc_df = pd.DataFrame()
  gyr_df = pd.DataFrame()
  acc_set = 1
  gyr_set = 1


  for f in files:



      df = pd.read_csv(f)

      data_Path = '/content/drive/MyDrive/FitnessTracker/FitnessTracker/data-science-template-main/data/raw/MetaMotion/'
      f = f.replace(data_Path,'')
      participant = f.split("-")[0]
      label = f.split("-")[1]
      category = f.split("-")[2].rstrip("13MetaWear_2019")


      df['participant'] = participant
      df['label'] = label
      df['category'] = category

      if "Accelerometer" in f:
        df['set'] = acc_set
        acc_set += 1
        acc_df = pd.concat([acc_df,df])

      if "Gyroscope" in f:
        df['set'] = acc_set
        gyr_set += 1
        gyr_df = pd.concat([gyr_df,df])

  acc_df.index = pd.to_datetime(acc_df['epoch (ms)'],unit= 'ms')
  gyr_df.index = pd.to_datetime(gyr_df['epoch (ms)'],unit= 'ms')

  del acc_df["epoch (ms)"]
  del acc_df['time (01:00)']
  del acc_df['elapsed (s)']


  del gyr_df["epoch (ms)"]
  del gyr_df['time (01:00)']
  del gyr_df['elapsed (s)']

  return acc_df,gyr_df
acc_df,gyr_df = read_data_file(files)

# %% [markdown]
# # Merging datasets

# %%
data_merged = pd.concat([acc_df.iloc[:,:3],gyr_df],axis = 1)

# %%
data_merged.head(2)
# Out:
#                          x-axis (g)  y-axis (g)  z-axis (g)  x-axis (deg/s)  \
# epoch (ms)
# 2019-01-11 15:08:04.950         NaN         NaN         NaN         -10.671
# 2019-01-11 15:08:04.990         NaN         NaN         NaN          -8.720
#
#                          y-axis (deg/s)  z-axis (deg/s) participant  label  \
# epoch (ms)
# 2019-01-11 15:08:04.950          -1.524           5.976           B  bench
# 2019-01-11 15:08:04.990          -2.073           3.171           B  bench
#
#                         category   set
# epoch (ms)
# 2019-01-11 15:08:04.950    heavy  65.0
# 2019-01-11 15:08:04.990    heavy  65.0

# %% [markdown]
# # column rename

# %%
data_merged.columns = [
    'acc_x',
    'acc_y',
    'acc_z',
    'gyr_x',
    'gyr_y',
    'gyr_z','label' ,
    'category' ,
    'participant' ,
    'set'
]

# %% [markdown]
# # Resample data (frequency conversion)

# %%
sampling = {
    'acc_x': 'mean',
    'acc_y': 'mean',
    'acc_z': 'mean',
    'gyr_x': 'mean',
    'gyr_y': 'mean',
    'gyr_z': 'mean',
    'label': "last" ,
    'category' : "last",
    'participant' : "last",
    'set': "last"
}

# %%
#apply mean for numerical and last for categorial features set is numerical and for this last is applied
data_merged[:1000].resample(rule = '200ms').apply(sampling)
# Out:
#                             acc_x     acc_y     acc_z    gyr_x    gyr_y  \
# epoch (ms)
# 2019-01-11 15:08:04.800       NaN       NaN       NaN -9.69550  -1.7985
# 2019-01-11 15:08:05.000       NaN       NaN       NaN -2.01220  -0.4270
# 2019-01-11 15:08:05.200  0.013500  0.977000 -0.071000 -1.89040   2.4392
# 2019-01-11 15:08:05.400 -0.001500  0.970500 -0.079500 -1.68260  -0.8904
# 2019-01-11 15:08:05.600  0.001333  0.971667 -0.064333  2.56080  -0.2560
# ...                           ...       ...       ...      ...      ...
# 2019-01-11 15:10:21.600 -0.174000  1.092667 -0.153333 -4.96360 -16.4026
# 2019-01-11 15:10:21.800 -0.219500  1.402500 -0.109000 -7.52440  18.6706
# 2019-01-11 15:10:22.000 -0.192000  0.871667 -0.155667  2.60980   8.7070
# 2019-01-11 15:10:22.200 -0.227000  0.891000 -0.170000  5.39020   4.0000
# 2019-01-11 15:10:22.400 -0.225500  0.919500 -0.205500  6.34125   0.5795
#
#                            gyr_z label category participant   set
# epoch (ms)
# 2019-01-11 15:08:04.800   4.5735     B    bench       heavy  65.0
# 2019-01-11 15:08:05.000  -1.6218     B    bench       heavy  65.0
# 2019-01-11 15:08:05.200   0.9388     B    bench       heavy  65.0
# 2019-01-11 15:08:05.400   2.1708     B    bench       heavy  65.0
# 2019-01-11 15:08:05.600  -1.4146     B    bench       heavy  65.0
# ...                          ...   ...      ...         ...   ...
# 2019-01-11 15:10:21.600  21.9026     A    bench       heavy  67.0
# 2019-01-11 15:10:21.800 -22.6828     A    bench       heavy  67.0
# 2019-01-11 15:10:22.000 -14.8658     A    bench       heavy  67.0
# 2019-01-11 15:10:22.200  -0.3780     A    bench       heavy  67.0
# 2019-01-11 15:10:22.400   9.9085     A    bench       heavy  67.0
#
# [689 rows x 10 columns]

# %%
# groups by days and gives   dataframe for each day
days = [g for n,g in data_merged.groupby(pd.Grouper(freq='D')) ]

# %%
 #merges the data frame of all days
data_resampled = pd.concat([df.resample(rule = '200ms').apply(sampling).dropna() for df in days])

# %%
data_resampled.head(2)
# Out:
#                           acc_x   acc_y   acc_z   gyr_x   gyr_y   gyr_z label  \
# epoch (ms)
# 2019-01-11 15:08:05.200  0.0135  0.9770 -0.0710 -1.8904  2.4392  0.9388     B
# 2019-01-11 15:08:05.400 -0.0015  0.9705 -0.0795 -1.6826 -0.8904  2.1708     B
#
#                         category participant   set
# epoch (ms)
# 2019-01-11 15:08:05.200    bench       heavy  65.0
# 2019-01-11 15:08:05.400    bench       heavy  65.0

# %%
data_resampled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9009 entries, 2019-01-11 15:08:05.200000 to 2019-01-20 17:33:27.800000
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   acc_x        9009 non-null   float64
#  1   acc_y        9009 non-null   float64
#  2   acc_z        9009 non-null   float64
#  3   gyr_x        9009 non-null   float64
#  4   gyr_y        9009 non-null   float64
#  5   gyr_z        9009 non-null   float64
#  6   label        9009 non-null   object
#  7   category     9009 non-null   object
#  8   participant  9009 non-null   object
#  9   set          9009 non-null   float64
# dtypes: float64(7), object(3)
# memory usage: 774.2+ KB

# %%
data_resampled['set'] = data_resampled['set'].astype(int)

# %% [markdown]
# # Export dataset

# %%
data_resampled.to_pickle('/content/drive/MyDrive/FitnessTracker/FitnessTracker/data-science-template-main/data/interim/data_resampled.pkl')
